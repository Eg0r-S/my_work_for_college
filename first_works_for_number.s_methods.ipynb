# %% [markdown]
# # Импорт библиотек.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Задание 2.3

# %% [markdown]
# ## Упражнение 2

# %% [markdown]
# Уточните наименьший по модулю отличного от нуля корень уравнения xsinx - 1 = 0 методом простой итерации с толщиной до 10^-5, используя расчётную таблицу и калькулятор, программу на ПК.

# %%
def f(x): return x * np.sin(x) - 1


x = np.linspace(-10, 10, 1000)


plt.figure(figsize=(10, 6))
plt.plot(x, f(x), 'b-', linewidth=2, label='f(x) = x*sin(x) - 1')
plt.axhline(y=0, color='k', linestyle='--', alpha=0.7)
plt.axvline(x=0, color='k', linestyle='--', alpha=0.7)
plt.grid(True, alpha=0.3)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('График функции f(x) = x*sin(x) - 1')
plt.legend()
plt.tight_layout()
plt.show()

# %%
def iterarion_f(x): return 1 / np.sin(x)    #Итерационная функция от x * Sin(x) - 1 = 0

def simple_iteration(x0, eps):
    table_data = []

    x_prev = x0
    x_new = iterarion_f(x_prev)
    iter_count = 1

    table_data.append({
            'Итерация': iter_count,
            'x_n': x_prev,
            'x_{n+1}': x_new,
            '|Δx|': abs(x_new - x_prev)
        })
    
    while abs(x_new - x_prev) > eps:
        x_prev = x_new
        x_new = iterarion_f(x_prev)
        iter_count += 1

        table_data.append({
            'Итерация': iter_count,
            'x_n': x_prev,
            'x_{n+1}': x_new,
            '|Δx|': abs(x_new - x_prev)
        })
    
    df = pd.DataFrame(table_data)
    df = df.round({
        'x_n': 6,
        'x_{n+1}': 6,
        '|Δx|': 8
    })

    return round(x_new, 5), df

# Изначальные значения
eps = 1e-5
x0 = 1.8


root, df = simple_iteration(x0, eps)


print(df.to_string(index=False))
print(f"\nНайденный наименьший по модулю корень уравнения: x ≈ {root}")
# Out:
#  Итерация      x_n  x_{n+1}     |Δx|
#         1 1.800000 1.026855 0.773145
#         2 1.026855 1.168667 0.141813
#         3 1.168667 1.086685 0.081982
#         4 1.086685 1.129830 0.043145
#         5 1.129830 1.105779 0.024051
#         6 1.105779 1.118801 0.013022
#         7 1.118801 1.111633 0.007168
#         8 1.111633 1.115544 0.003911
#         9 1.115544 1.113400 0.002144
#        10 1.113400 1.114572 0.001173
#        11 1.114572 1.113930 0.000642
#        12 1.113930 1.114281 0.000351
#        13 1.114281 1.114089 0.000192
#        14 1.114089 1.114194 0.000105
#        15 1.114194 1.114137 0.000058
#        16 1.114137 1.114168 0.000032
#        17 1.114168 1.114151 0.000017
#        18 1.114151 1.114160 0.000009
#
# Найденный наименьший по модулю корень уравнения: x ≈ 1.11416

# %% [markdown]
# # Задание 2.5

# %% [markdown]
# ## Упражнение 1

# %% [markdown]
# Сопоставляя рис. 2.10, 2.11 и 2.12, проиллюстрируйте графически решение уравнения методами хорд и касательных для всех четырех ситуаций, изображенных на рис. 2.9.

# %%
# Функция 1: парабола вверх (F'>0, F''>0)
def f(x): return (x - 1.5)**2 - 0.5
root = 1.5 + np.sqrt(0.5)

x = np.linspace(0.5, 2.8, 200)
y = f(x)

plt.figure(figsize=(5, 5))
plt.title('Случай a): F\' > 0, F\'\' > 0', fontsize=12, fontweight='bold')

plt.plot(x, y, 'b-', linewidth=2.5, label='f(x)')
plt.scatter(root, f(root), color='black', zorder=5, label='Корень')
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

print(f'Корень = {root:.2f}')
# Out:
# Корень = 2.21

# %%
# Функция 2: парабола вниз (F'<0, F''<0)
f = lambda x: -(x - 1.5)**2 + 0.5
root = 1.5 - np.sqrt(0.5)

x = np.linspace(0.5, 2.8, 200)
y = f(x)

plt.figure(figsize=(5, 5))
plt.plot(x, y, 'b-', linewidth=2.5, label='f(x)')
plt.scatter(root, f(root), color='black', zorder=5, label='Корень')

plt.title('Случай b): F\' < 0, F\'\' < 0', fontsize=12, fontweight='bold')
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

print(f'Корень = {root:.2f}')
# Out:
# Корень = 0.79

# %%
# Функция 3: убывающая, вогнутая вверх (F'<0, F''>0)
def f(x): return -np.sqrt(x - 1) + 0.5
root = 1.25

x = np.linspace(1.0, 2.8, 200)  # область определения от 1
y = f(x)

plt.figure(figsize=(5, 5))
plt.plot(x, y, 'b-', linewidth=2.5, label='f(x)')
plt.scatter(root, f(root), color='black', zorder=5, label='Корень')

plt.title('Случай c): F\' < 0, F\'\' > 0', fontsize=12, fontweight='bold')
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

print(f'Корень = {root:.2f}')
# Out:
# Корень = 1.25

# %%
# Функция 4: возрастающая, вогнутая вниз (F'>0, F''<0)
def f(x): return np.sqrt(2.5 - x) - 0.5
root = 2.25

x = np.linspace(0.5, 2.5, 200)  # область определения до 2.5
y = f(x)

plt.figure(figsize=(5, 5))
plt.plot(x, y, 'b-', linewidth=2.5, label='f(x)')
plt.scatter(root, f(root), color='black', zorder=5, label='Корень')

plt.title('Случай d): F\' > 0, F\'\' < 0', fontsize=14, fontweight='bold')
plt.grid(True, linestyle=':', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Упражнение 2:

# %% [markdown]
# Комбинационным методом хорд и касательных уточните до 0.000001 корень уравнения x^3 + 3x^2 - 24x + 1 = 0 на отрезке [0;1]

# %%
def f(x):
    return x**3 - 3 * x**2 - 24 * x + 1

def df(x):
    return 3 * x**2 - 6 * x - 24  # Производная функция

def df2(x):
    return 6 * x - 6  # Вторая производная функции

def solve_combined(a, b, eps):

    # Определяю, с какой стороны касательная (x_k), а с какой хорда (x_n)
    if f(a) * df2(a) > 0:
        x_k, x_n = a, b
    else:
        x_k, x_n = b, a
    
    # Списки для таблицы
    it = []
    x_ns = []
    x_ks = []

    iteration = 0
    while abs(x_n - x_k) > eps:

        # Временно создаю новые переменные, чтобы изменения не мешали друг другу.
        x_n_new = x_n - (f(x_n) * (x_k - x_n)) / (f(x_k) - f(x_n))
        x_k_new = x_k - f(x_k) / df(x_k)
        
        x_n, x_k = x_n_new, x_k_new


        # Добавляю данные в списки
        x_ns.append(x_n)
        x_ks.append(x_k)
        iteration += 1
        it.append(iteration)
    

    # Создаю таблицу
    data = {'Итерации': it, 'x_n': x_ns, 'x_k': x_ks}
    dff = pd.DataFrame(data)
    dff = dff.set_index('Итерации')
    print(dff)

    root = (x_n + x_k) / 2
    print(f'\n{round(float(root), 6)}')


# Изначальные параметры
a = 0
b = 1
eps = 1e-6  # Точность

solve_combined(a, b, eps)
# Out:
#                x_n       x_k
# Итерации
# 1         0.038462  0.074074
# 2         0.041443  0.041577
# 3         0.041455  0.041455
#
# 0.041455

# %% [markdown]
# # Задание 2.6

# %% [markdown]
# ## №1

# %%
def f1(x):
    return np.log10(x)

def f2(x):
    return np.cos(x)


# Если f_diff = 0, то корень найден.
def f_diff(x):
    return f1(x) - f2(x)


# Диапазон x (с учетом области определения ln: x > -6.1)
x_plot = np.linspace(-6.0, 10, 1000)


# Графики функций
plt.figure(figsize=(8, 5))
plt.plot(x_plot, f1(x_plot), label=r'$y = \ln(x + 6.1)$', color='blue', linewidth=2)
plt.plot(x_plot, f2(x_plot), label=r'$y = 2\sin(x - 1.4)$', color='red', linestyle='--')


# Оформление графика
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, linestyle=':', alpha=0.7)
plt.title('Графический метод отделения корней')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# C:\Users\a1v2f5\AppData\Local\Temp\ipykernel_24592\1661710884.py:2: RuntimeWarning: invalid value encountered in log10
#   return np.log10(x)

# %%
# Определяю функцию f(x) = ln(x + 6.1) - 2*sin(x - 1.4)
def f(x):
    return np.log10(x) - np.cos(x)

def bisection_method(a, b, eps):

    # Проверка условия теоремы Больцано-Коши
    if f(a) * f(b) > 0:
        print("На данном отрезке корней нет или их четное количество")
        return None
    

    # Списки для таблицы
    it = []
    ass = []
    bs = []
    result = []

    
    iteration = 0
    while (b - a) / 2 > eps:
        
        mid = (a + b) / 2


        # Выбираю половину отрезка, на которой функция меняет знак
        if f(a) * f(mid) < 0:
            b = mid
        else:
            a = mid
        

        # Добавляю в списки данные
        ass.append(round(a, 4))
        bs.append(round(b, 4))
        result.append(round(mid, 4))
        iteration += 1
        it.append(iteration)
    

    # Создание таблицы
    data = {'Итерации': it, 'a': ass, 'b': bs, 'result': result}
    df = pd.DataFrame(data)
    df = df.set_index('Итерации')

    return df, (a + b) / 2

# Беру интервал [-6;-5], потому что на этом интервале должен быть только 1 корень.
a, b = 1, 2
epsilon = 1e-4 # Точность

df, root = bisection_method(a, b, epsilon)

if root is not None:
    print(df)
    print(f"\nКорень уравнения: {root:.4f}")
# Out:
#                a       b  result
# Итерации
# 1         1.0000  1.5000  1.5000
# 2         1.2500  1.5000  1.2500
# 3         1.3750  1.5000  1.3750
# 4         1.3750  1.4375  1.4375
# 5         1.4062  1.4375  1.4062
# 6         1.4062  1.4219  1.4219
# 7         1.4141  1.4219  1.4141
# 8         1.4180  1.4219  1.4180
# 9         1.4180  1.4199  1.4199
# 10        1.4180  1.4189  1.4189
# 11        1.4180  1.4185  1.4185
# 12        1.4182  1.4185  1.4182
# 13        1.4183  1.4185  1.4183
#
# Корень уравнения: 1.4184

# %% [markdown]
# ![{51698EE3-AF20-41FA-9332-B7212F560FDE}.png](attachment:{51698EE3-AF20-41FA-9332-B7212F560FDE}.png)

# %% [markdown]
# ## №2

# %%
# Определяю функцию f(x) = ln(x + 6.1) - 2*sin(x - 1.4)
def f(x):
    return x**2 - 3.2 * x - 1

def bisection_method(a, b, eps):

    # Проверка условия теоремы Больцано-Коши
    if f(a) * f(b) > 0:
        print("На данном отрезке корней нет или их четное количество")
        return None
    

    # Списки для таблицы
    it = []
    ass = []
    bs = []
    result = []

    
    iteration = 0
    while (b - a) / 2 > eps:
        
        mid = (a + b) / 2


        # Выбираю половину отрезка, на которой функция меняет знак
        if f(a) * f(mid) < 0:
            b = mid
        else:
            a = mid
        

        # Добавляю в списки данные
        ass.append(round(a, 4))
        bs.append(round(b, 4))
        result.append(round(mid, 4))
        iteration += 1
        it.append(iteration)
    

    # Создание таблицы
    data = {'Итерации': it, 'a': ass, 'b': bs, 'result': result}
    df = pd.DataFrame(data)
    df = df.set_index('Итерации')

    return df, (a + b) / 2

# Беру интервал [-6;-5], потому что на этом интервале должен быть только 1 корень.
a, b = 2, 4
epsilon = 1e-4 # Точность

df, root = bisection_method(a, b, epsilon)

if root is not None:
    print(df)
    print(f"\nКорень уравнения: {root:.4f}")
# Out:
#                a       b  result
# Итерации
# 1         3.0000  4.0000  3.0000
# 2         3.0000  3.5000  3.5000
# 3         3.2500  3.5000  3.2500
# 4         3.3750  3.5000  3.3750
# 5         3.4375  3.5000  3.4375
# 6         3.4688  3.5000  3.4688
# 7         3.4844  3.5000  3.4844
# 8         3.4844  3.4922  3.4922
# 9         3.4844  3.4883  3.4883
# 10        3.4863  3.4883  3.4863
# 11        3.4863  3.4873  3.4873
# 12        3.4863  3.4868  3.4868
# 13        3.4866  3.4868  3.4866
# 14        3.4867  3.4868  3.4867
#
# Корень уравнения: 3.4868

# %% [markdown]
# ![{BD4CB80F-45CA-4263-8A24-870E9F0D072D}.png](attachment:{BD4CB80F-45CA-4263-8A24-870E9F0D072D}.png)

# %% [markdown]
# ![{4A155C14-C08A-48AA-9ABA-6AA8C47A80DE}.png](attachment:{4A155C14-C08A-48AA-9ABA-6AA8C47A80DE}.png)

# %% [markdown]
# ## №3

# %%
def phi(x):

    # Преобразованная функция f(x) = ln(x + 6.1) - 2*sin(x - 1.4) в вид x = exp(2*sin(x - 1.4)) - 6.1
    return 1 + 0.75 * np.ln(x)

def simple_iteration(x0, eps):


    # Списки для данных
    it = []
    x_olds = []
    x_news = []
    
    x_old = x0
    x_new = phi(x_old)
    iterations = 1

    it.append(iterations)
    x_olds.append(x_old)
    x_news.append(x_new)

    while abs(x_new - x_old) > eps:
        x_old = x_new
        x_new = phi(x_old)
        iterations += 1


        # Добавление данных в списки
        it.append(iterations)
        x_olds.append(x_old)
        x_news.append(x_new)
    
    # Создание таблицы
    data = {'Итерации': it, 'x_old': x_olds, 'x_new': x_news}
    df = pd.DataFrame(data)
    df = df.set_index('Итерации')
    return df, x_new

# Начальные параметры
x_start = -6.0  
precision = 1e-6    # Точность

simple_iteration(x_start, precision)
df, root = simple_iteration(x_start, precision)

print(df)
print(f"\nКорень уравнения: {root:.6f}")
